# %%
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/qk/tqkgvx4x5q53p9c2fm0nl04r0000gn/T/ipykernel_6168/1662815981.py in <module>
# ----> 1 import numpy as np
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'

# %%
csv_file = 'data/data_python.csv'

# %%
df = pd.read_csv(csv_file)
df.info()
# df.describe()
df
# df.apply(lambda x: x.upper())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   website       45 non-null     object
#  1   extract_time  45 non-null     float64
#  2   total_posts   45 non-null     int64
#  3   posts_python  45 non-null     int64
#  4   posts         45 non-null     object
#  5   created_date  45 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.2+ KB
#             website  extract_time  total_posts  posts_python  \
# 0   www.cvbankas.lt        152.80         5495            28
# 1   www.cvbankas.lt         86.41         5743            28
# 2   www.cvbankas.lt         86.06         5848            27
# 3   www.cvbankas.lt         85.74         5706            29
# 4   www.cvbankas.lt         83.31         5564            26
# 5   www.cvbankas.lt        133.36         5334            27
# ...

# %%
df[['total_posts','posts_python', 'posts']]
# Out:
#     total_posts  posts_python  \
# 0          5495            28
# 1          5743            28
# 2          5848            27
# 3          5706            29
# 4          5564            26
# 5          5334            27
# 6          5335            27
# 7          5118            27
# 8          5495            27
# 9          5870            27
# 10         6255            25
# 11         6106            28
# 12         6415            30
# 13         6734            33
# 14         6948            36
# 15         6994            36
# 16         6992            35
# 17         6778            32
# 18         6625            32
# 19         6818            35
# 20         7052            36
# 21         7301            40
# 22         7114            39
# 23         7114            39
# 24         7244            39
# 25         7382            40
# 26         7382            40
# 27         7215            38
# 28         7470            40
# 29         7295            40
# ...

# %%
df['website'].apply(lambda x: x.upper())
# Out:
# 0     WWW.CVBANKAS.LT
# 1     WWW.CVBANKAS.LT
# 2     WWW.CVBANKAS.LT
# 3     WWW.CVBANKAS.LT
# 4     WWW.CVBANKAS.LT
# 5     WWW.CVBANKAS.LT
# 6     WWW.CVBANKAS.LT
# 7     WWW.CVBANKAS.LT
# 8     WWW.CVBANKAS.LT
# 9     WWW.CVBANKAS.LT
# 10    WWW.CVBANKAS.LT
# 11    WWW.CVBANKAS.LT
# 12    WWW.CVBANKAS.LT
# 13    WWW.CVBANKAS.LT
# 14    WWW.CVBANKAS.LT
# 15    WWW.CVBANKAS.LT
# 16    WWW.CVBANKAS.LT
# 17    WWW.CVBANKAS.LT
# 18    WWW.CVBANKAS.LT
# 19    WWW.CVBANKAS.LT
# 20    WWW.CVBANKAS.LT
# 21    WWW.CVBANKAS.LT
# 22    WWW.CVBANKAS.LT
# 23    WWW.CVBANKAS.LT
# 24    WWW.CVBANKAS.LT
# 25    WWW.CVBANKAS.LT
# 26    WWW.CVBANKAS.LT
# 27    WWW.CVBANKAS.LT
# 28    WWW.CVBANKAS.LT
# 29    WWW.CVBANKAS.LT
# 30    WWW.CVBANKAS.LT
# 31    WWW.CVBANKAS.LT
# 32    WWW.CVBANKAS.LT
# 33    WWW.CVBANKAS.LT
# 34    WWW.CVBANKAS.LT
# 35    WWW.CVBANKAS.LT
# 36    WWW.CVBANKAS.LT
# 37    WWW.CVBANKAS.LT
# 38    WWW.CVBANKAS.LT
# 39    WWW.CVBANKAS.LT
# 40    WWW.CVBANKAS.LT
# ...

# %%
tposts = df['total_posts'].to_string(index=False).split('\n')
tposts
# Out:
# ['5495',
#  '5743',
#  '5848',
#  '5706',
#  '5564',
#  '5334',
#  '5335',
#  '5118',
#  '5495',
#  '5870',
#  '6255',
#  '6106',
#  '6415',
#  '6734',
#  '6948',
#  '6994',
#  '6992',
#  '6778',
#  '6625',
#  '6818',
#  '7052',
#  '7301',
#  '7114',
#  '7114',
#  '7244',
#  '7382',
#  '7382',
#  '7215',
#  '7470',
#  '7295',
#  '7306',
#  '7179',
#  '7173',
#  '7175',
#  '7177',
#  '7403',
#  '7827',
#  '7983',
#  '7988',
#  '7769',
#  '7994',
#  '7831',
#  '7837',
#  '7696',
#  '7699']

# %%
posts = df['posts']
pd.DataFrame(posts)

# df['posts']
# Out:
#                                                 posts
# 0   [{'post_descrip': "\n\nOur team\nThe Service D...
# 1   [{'post_descrip': "\n\nOur team\nThe Service D...
# 2   [{'post_descrip': "\n\nOur team\nThe Service D...
# 3   [{'post_descrip': '\n\nDarbo pobūdis\nTranspor...
# 4   [{'post_descrip': '\n\nKą veiksi pas mus?\nSus...
# 5   [{'post_descrip': '\n\nKą veiksi pas mus?\nSus...
# 6   [{'post_descrip': '\n\nKą veiksi pas mus?\nSus...
# 7   [{'post_descrip': '\n\nKą veiksi pas mus?\nSus...
# 8   [{'post_descrip': "\n\nSEB is a leading financ...
# 9   [{'post_descrip': '\n\nAardvark Technologies W...
# 10  [{'post_descrip': '\n\nAardvark Technologies W...
# 11  [{'post_descrip': '\n\nJob description:\nMetid...
# 12  [{'post_descrip': '\n\nJob Description:\nA gre...
# 13  [{'post_descrip': '\n\nJob description\nGP Tra...
# 14  [{'post_descrip': '\n\nAbout the position:\nTh...
# 15  [{'post_descrip': "\n\nDo You want to be part ...
# ...

# %%
posts = df['posts']
x = df['posts'].head(1)
# x
# pd.DataFrame(x)
# posts.head(1)
# posts.loc[1]
h = pd.DataFrame(posts.head(1))

# %%
# posts = df['posts']
po =pd.DataFrame(df['posts'])#, index=nubers)#,  v, "post_id","applicants","company","position","post_url","img_url","salary","city","upload_post","time_public"])

z = pd.DataFrame.from_dict(po.iloc[1])
pd.DataFrame(df['posts'].head(1))
po.iloc[1]

# pd.DataFrame.from_dict(po.loc[1,"post_descrip"])
# d data in a list of dictionary
# book = [{'id':1,'name':'python','price':56,'no_of_pages':34},
#         {'id':2,'name':'Node-js','price':45,'no_of_pages':54},
#         {'id':3,'name':'R','price':100,'no_of_pages':80},
#         {'id':4,'name':'Html','price':16,'no_of_pages':20}]

# # pass this book to the dataframe 
# dataframe=pandas.DataFrame.from_records(book)

# display dataframe
# Out:
# posts    [{'post_descrip': "\n\nOur team\nThe Service D...
# Name: 1, dtype: object

# %%
pd.DataFrame(po.iloc[1], columns=["post_descrip", "post_id","applicants","company","position","post_url","img_url","salary","city","upload_post","time_public"])
# Out:
# Empty DataFrame
# Columns: [post_descrip, post_id, applicants, company, position, post_url, img_url, salary, city, upload_post, time_public]
# Index: []

# %%
# pd.DataFrame(df)
pd.DataFrame.from_dict(x)
# pd.DataFrame.from_records(posts)
# Out:
#                                                posts
# 0  [{'post_descrip': "\n\nOur team\nThe Service D...
